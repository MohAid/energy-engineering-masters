# %% [markdown]
# # الأسس وبناء دالة الخسارة — متذبذب توافقي مخمد
#
# مقارنة شبكة مستنيرة بالفيزياء بشبكة تتعلم من البيانات وحدها.
#
# نفّذ الخلايا بالترتيب. الدفتر ينزّل البرنامج من المستودع ثم يشغّله على معالج Colab المجاني.

# %%
# !pip -q install torch numpy matplotlib

# %%
# !wget -q -O exp1_oscillator.py https://raw.githubusercontent.com/MohAid/energy-engineering-masters/main/courses/05-pinn/projects/pinn-01-oscillator-foundations/src/exp1_oscillator.py
print(open('exp1_oscillator.py').read()[:1500])

# %%
# !python exp1_oscillator.py

# %% [markdown]
# ## الأشكال

# %%
from IPython.display import Image, display
for f in ['fig1_naive_vs_pinn.png', 'fig2_losses.png', 'fig3_variants.png']:
    display(Image('out_exp1/' + f))
